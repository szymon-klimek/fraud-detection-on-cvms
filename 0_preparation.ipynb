# %% [markdown]
# # Prepare working environment
#
# Create all needed folders and install components.

# %% [markdown]
# Create dowload folder and install required packages

# %%
! mkdir -p downloaded_datasets
! pip install azure.storage.blob > /dev/null

# %% [markdown]
# Copy azure token secret from Sealed Secrets to file inside memory:

# %%
! cp /sealed/azure-value/azure-sas /demo/azure-token

# %% [markdown]
# Download the required packages. This could have been done in the Dockerfile used to build this application, but since we want to show an original unaltered image running on CoCo, we need to manually install them into `quay.io/jupyter/base-notebook:latest`.

# %%
# This command takes a bit
! pip install onnx onnxruntime tf2onnx pandas keras tensorflow scikit-learn==1.7.2 tf2onnx onnx pathlib matplotlib colorama
